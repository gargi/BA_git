# %% [raw]
# All data provided by the challenge- and the opencern-dataset was \cite{higgsPaper}

# %% [markdown]
# The features Weight and Label were originally only provided in the training-dataset. The data used in this thesis is expanded by complete Weight-, Labels-features and the Kaggle-specific features KaggleSet and KaggleWeight.
#
# All features of the dataset are described in Appendix A.

# %% [markdown]
# reducing features by using their relationship with PRI_jet_num

# %%
import kaggleData as kD
import toolbox as tb
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import os

# %%
scriptFolderPath = os.path.dirname(os.getcwd())
mainFolderPath = os.path.dirname(scriptFolderPath)
plotPath = (mainFolderPath + "/Plots")
scatterPath = (plotPath + "/Scatter") 
histPath = (plotPath + "/Hist")

# %%
csv_data,csv_header = kD.csvToArray()

# %%
csv_data[:,csv_header.index("Weight")].astype(float).cumsum()[-1]
# Out:
# 411691.83592894807

# %%
train_data,train_header,test_data,test_header=kD.getOriginalKaggleSets(csv_data,csv_header)

# %%
test_data = kD._extractKaggleDataset(csv_data,csv_header,["b","v"])

# %%
test_labels = kD._extractFeature("Label",test_data ,csv_header,dtype="<U16")
test_labels = kD.translateLabels(test_labels,["Label"]).astype(float)

# %%
#cut, if given, EventId and Weight, preserve Label as new array, pls
train_all = train_data[:,1:-1].astype(float)
train_labels = kD.translateLabels(train_data[:,-1],["Label"]).astype(float)
test_all = test_data[:,1:-3].astype(float)
header_all = test_header[1:]

#4.617290019989014 sec

# %%
train_header
# Out:
# ['EventId',
#  'DER_mass_MMC',
#  'DER_mass_transverse_met_lep',
#  'DER_mass_vis',
#  'DER_pt_h',
#  'DER_deltaeta_jet_jet',
#  'DER_mass_jet_jet',
#  'DER_prodeta_jet_jet',
#  'DER_deltar_tau_lep',
#  'DER_pt_tot',
#  'DER_sum_pt',
#  'DER_pt_ratio_lep_tau',
#  'DER_met_phi_centrality',
#  'DER_lep_eta_centrality',
#  'PRI_tau_pt',
#  'PRI_tau_eta',
#  'PRI_tau_phi',
#  'PRI_lep_pt',
#  'PRI_lep_eta',
#  'PRI_lep_phi',
#  'PRI_met',
#  'PRI_met_phi',
#  'PRI_met_sumet',
#  'PRI_jet_num',
#  'PRI_jet_leading_pt',
#  'PRI_jet_leading_eta',
#  'PRI_jet_leading_phi',
#  'PRI_jet_subleading_pt',
#  'PRI_jet_subleading_eta',
#  'PRI_jet_subleading_phi',
#  'PRI_jet_all_pt',
#  'KaggleWeight',
#  'Label']

# %%
train_all[:,-1]
# Out:
# array([ 0.00265331,  2.23358449,  2.34738894, ...,  0.01863612,
#         1.68161144,  1.87747381])

# %%
train_all[:,-1].cumsum()[-1]
# Out:
# 411691.83592984255

# %%
def countErrorsByJets(featlist,header,data):
    index_PRI_jet_num = np.int(header.index("PRI_jet_num"))
    ######### 0 1 2 3 #########
    totals = np.zeros((4),dtype=np.int)
    errors = np.zeros((4,len(featlist)),dtype=np.int)
    for i in range(0,len(data[:,index_PRI_jet_num])):
        jets = np.int(data[i,index_PRI_jet_num])
        totals[jets] += 1
        for j in range(0,len(featlist)):
            feat = featlist[j]
            index_feat = np.int(header.index(feat))
            if np.float(data[i,index_feat]) == -999.0:
                errors[jets,j] +=1
    return totals,errors

# %%
def plot_PJN_Errors(featlist,header,data):
    totals,errors = countErrorsByJets(featlist,header,data)

    font = {'weight' : 'bold',
            'size'   : 10}


    #fig = plt.figure(figsize=(15,10))
    
    b = 0
    colors = ['green','red','blue','grey']
    plot = [0,0,0,0]
    for i in [0,1,2,3]:
        plot[i] = plt.bar(left = np.arange(len(featlist)), height = errors[i,:],
               bottom = b, color=colors[i], alpha=0.5)
        b += errors[i,:]
        
    #yticks = np.linspace(0,totals.cumsum()[-1])
    plt.yticks(np.unique(b))
    #plt.xticks(np.arange(31))
    
    plt.ylabel('Error-Values')
    plt.xlabel('Features')
    plt.title('Error-Values in features related to PRI_jet_num (Pjn)')

    plt.xticks(np.arange(len(featlist)), featlist, rotation=90)
    matplotlib.rc('font', **font)
    plt.legend((plot[0][0],plot[1][0],plot[2][0],plot[3][0]), ('Pjn = 0', 'Pjn = 1','Pjn = 2','Pjn = 3',), loc = 9)
    return plt

# %%
# %pylab inline
mainFig = plt.figure(figsize = (10,5))
mainFig.add_subplot(111)
ax = plot_PJN_Errors(header_all,csv_header,csv_data);
#mainFig.savefig(plotPath + "/PJN_Errors")
#plt.close("all")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# We extract all featurenames which contain errors

# %%
totals,errors = countErrorsByJets(header_all,csv_header,csv_data)
errorFeatures = []
for i in range(0,len(header_all)):
    if errors[0,i] != 0:
        errorFeatures.append(header_all[i])

# %% [markdown]
# We still want DER_mass_MMC, it is a valuable feature, as other tests had shown

# %%
errorFeatures.remove('DER_mass_MMC')

# %%
errorFeatures
# Out:
# ['DER_deltaeta_jet_jet',
#  'DER_mass_jet_jet',
#  'DER_prodeta_jet_jet',
#  'DER_lep_eta_centrality',
#  'PRI_jet_leading_pt',
#  'PRI_jet_leading_eta',
#  'PRI_jet_leading_phi',
#  'PRI_jet_subleading_pt',
#  'PRI_jet_subleading_eta',
#  'PRI_jet_subleading_phi']

# %%
def scaleAxis(data,cutPercent):
    sData = sorted(data)
    l = len(sData)
    cutPoint = int(cutPercent*l/100)
    axisMax = sData[l - cutPoint]
    axisMin = sData[cutPoint]
    if axisMin == -999.0:
        for x in sData:
            if x > axisMin:
                axisMin = x
                break
    return axisMin,axisMax

# %%
def generateLabelsColors(labels):
    colors = []
    for i in range(0,len(labels)):
        label = labels[i]
        if label == 1:
            labelColor = "b" ##signal = blue
        elif label == 0:
            labelColor = "r" ##background = red
        else:
            print("ERROR in Labels!")
        colors.append(labelColor)
    return colors

# %%
def scattered(xName,yName,xData,yData,labels, alph=0.2):
    font = {'size'   : 20}
    colors = generateLabelsColors(labels)

    scale = 0.5
    xmin,xmax = scaleAxis(xData,scale)
    ymin,ymax = scaleAxis(yData,scale)
    
    scat = plt.scatter(xData, yData, s=1, edgecolor="", c=colors, alpha=alph)   
    
    plt.xlabel(xName)
    plt.ylabel(yName)
    
    plt.axis([xmin,xmax,ymin,ymax])
    
    title = ("Scatterplot: "+ xName+ " to "+ yName)
    
    blue_patch = mpatches.Patch(color='blue', label='signal')
    red_patch = mpatches.Patch(color='red', label='background')
    plt.legend(handles=[blue_patch,red_patch])
    matplotlib.rc('font', **font)
    plt.title(title)
    
    return plt

# %%
xName = "DER_mass_MMC"
yName = "DER_mass_transverse_met_lep"

xData = test_all[:,header_all.index(xName)]
yData = test_all[:,header_all.index(yName)]
labels = test_labels

mainFig = plt.figure(figsize=(12,9))
ax = mainFig.add_subplot(111)
ax = scattered(xName,yName,xData,yData,test_labels, alph=0.2)
savePath = ("/BA_git/Docs/latex/Thesis/src/v4/images/" + "scat_" + xName + "to" + yName)
#mainFig.savefig(savePath)

# %%
def createAllScatterplots(header,data,labels,scatterPath,startX=1,x_size=3,y_size=2,n=0):
    for x in range(startX,len(header)):
        xName = header[x]
        xData = data[:,x]
        xFolder = (scatterPath + "/" + xName)
        if not os.path.exists(xFolder):
            os.makedirs(xFolder)
        y = 1
        while y in range(1,len(header)):
            mainFig = plt.figure(figsize=(20,15))
            for i in range(1,(1+(x_size*y_size))):
                yName = header[y]
                yData = data[:,y]    
                ax = mainFig.add_subplot(x_size,y_size,i)
                y += 1
                ax = scattered(xName,yName,xData,yData,labels)

            savePath = (xFolder + "/" + str(n))
            n += 1
            mainFig.savefig(savePath)
            mainFig = None
            
        plt.close("all")

# %%
start = header_all.index("PRI_lep_pt")
n = (start-1)*5
#createAllScatterplots(header_all,test_all,test_labels,scatterPath,startX=start,n=n)

# %%
def histo(featName,data,labels):
    font = {'size'   : 20}

    b = 100

    title = str("Histogram: "+ featName)
    sdata = []
    bdata = []
    for i in range(0,len(data)):
        if labels[i] == 0:
            bdata.append(data[i])
        else:
            sdata.append(data[i])

    colors = generateLabelsColors(labels)
    
    scale = 0.1
    xmin,xmax = scaleAxis(data,scale)
    
    xmin = int(xmin)
    xmax = int(xmax)

    shist = plt.hist(sdata,bins = np.linspace(xmin,xmax,b), normed=1, facecolor='blue', alpha=0.3)
    bhist = plt.hist(bdata,bins = np.linspace(xmin,xmax,b), normed=1, facecolor='red', alpha=0.3)

    plt.legend(('Signal', 'Background'))

    plt.ylabel('Percentage in data')
    plt.xlabel('Values')
    plt.title(title)
    matplotlib.rc('font', **font)
    return plt

# %%
def createAllHistograms(header,data,labels,histPath,x=3,y=2):
    n = 0
    p = 1
    while p in range(1,len(header)):
        mainFig = plt.figure(figsize=(20,15))
        for i in range(1,(1+(x*y))):
            featName = header[p]
            feat_data = data[:,p]    
            ax = mainFig.add_subplot(x,y,i)
            ax = histo(featName,feat_data,labels);
            p += 1
        savePath = (histPath + "/hist_" + str(n))
        n += 1
        mainFig.savefig(savePath)
        
        mainFig = None
        plt.close("all")

# %%
# %pylab inline
xName = "DER_deltaeta_jet_jet"

xData = test_all[:,header_all.index(xName)]
labels = test_labels

mainFig = plt.figure(figsize=(12,9))
ax = mainFig.add_subplot(111)
ax = histo(xName,xData,test_labels)
savePath = ("/BA_git/Docs/latex/Thesis/src/v4/images/hist_" + xName)
#mainFig.savefig(savePath)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#createAllHistograms(header,test_data,test_labels,histPath)

# %%
pubLB,privLB = kD.getLeaderBoards()

# %%
sortedPriv=tb.sortByColumn(privLB,0)
sortedPub=tb.sortByColumn(pubLB,0)

# %% [markdown]
# Differences in Leaderboards:

# %% [markdown]
# ranks: PubLB vs PrivLB

# %%
rankdiff = np.copy(sortedPub[:,2]-sortedPriv[:,2])
abs_rankdiff = abs(np.copy(sortedPub[:,2]-sortedPriv[:,2]))
scorediff = np.copy(sortedPub[:,1]-sortedPriv[:,1])
abs_scorediff = abs(np.copy(sortedPub[:,1]-sortedPriv[:,1]))

# %%
# %pylab inline

font = {'size'   : 20}

mainFig = plt.figure(figsize=(12,9))
ax = mainFig.add_subplot(111)

xData = sortedPub[:,2]
yData = sortedPriv[:,2]

#colors = generateLabelsColors(labels)

#scale = 0.5
#xmin,xmax = scaleAxis(xData,scale)
#ymin,ymax = scaleAxis(yData,scale)
plt.Normalize()
scat = plt.scatter(xData, yData, s=100, edgecolor="gray",  c=rankdiff, cmap="jet")   
  
xName = "Public Rank"
yName = "Private Rank"
    
overridex = {
    'fontsize'            : 'xx-large',
    'verticalalignment'   : 'top',
    'horizontalalignment' : 'center'
    }

overridey = {
   'fontsize'            : 'xx-large',
   'verticalalignment'   : 'baseline',
   'horizontalalignment' : 'center',
   'rotation'            : 'vertical'
}

plt.xlabel(xName,overridex)
plt.ylabel(yName,overridey)

xmax = 1850
xmin = -50
    
plt.axis([xmax,xmin,xmax,xmin])

x = np.arange(xmin,xmax)
xy = plt.plot(x,x,color="black")

title = ("Shake-Up of 'The Higgs Boson Machine Learning Challenge'")

coord = int(abs(xmax-xmin)/2)


matplotlib.rc('font', **font)
plt.title(title)

cbar = plt.colorbar()
cbar.set_label("Rank-Difference (= |private rank - public rank|)")

plt.annotate("difference = 0",xy = (coord,coord), xytext=(+100,-200),
             xycoords = "data", textcoords='offset points',
             arrowprops = dict(arrowstyle="-"))

savePath = ("F:\BA_git\Docs\latex\Thesis\src\\v4\images" + "\\" + "shakeup")
mainFig.savefig(savePath)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
percentual_diff_score = abs_scorediff.copy()
percentual_diff_score[:]= abs_scorediff[:]/sortedPub[:,1]
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
rankdiff.min()
# Out:
# -720.0

# %%
# %pylab inline

font = {'size'   : 15}

mainFig = plt.figure(figsize=(20,15))
ax = mainFig.add_subplot(111)

xData = sortedPub[:,2]
yData = sortedPriv[:,2]

#colors = generateLabelsColors(labels)

#scale = 0.5
#xmin,xmax = scaleAxis(xData,scale)
#ymin,ymax = scaleAxis(yData,scale)
    
scat = plt.scatter(xData, yData, s=150, edgecolor="gray",  c=percentual_diff_score, cmap="jet")   
  
xName = "Public Rank"
yName = "Private Rank"
    
plt.xlabel(xName)
plt.ylabel(yName)

xmin = 1769
#xmin = 1000
#xmin = 500
xmax = -10
    
plt.axis([xmin,xmax,xmin,xmax])
#plt.axis([1000,1,1000,1])
#plt.axis([500,1,500,1])

x = np.arange(xmax,xmin)
xy = plt.plot(x,x,color="black")


title = ("Scatterplot: "+ xName+ " to "+ yName)

coord = int(abs(xmax-xmin)/2)
    
#blue_patch = mpatches.Patch(color='blue', label='signal')
#red_patch = mpatches.Patch(color='red', label='background')
#plt.legend(handles=[blue_patch,red_patch])
matplotlib.rc('font', **font)
plt.title(title)

cbar = plt.colorbar()
cbar.set_label("Score-Difference (= abs(private ams - public ams))")

plt.annotate("difference = 0",xy = (coord,coord), xytext=(+100,-200),
             xycoords = "data", textcoords='offset points',
             arrowprops = dict(arrowstyle="-"))

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['title']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
mainFig = plt.figure(figsize=(20,15))
ax = mainFig.add_subplot(111)

b = 100

title = "Histogram on public and private AMS-Scores"
xmin = privLB[:,1].min()
#xmin = -50
xmax = privLB[:,1].max()
#xmax = 50

hist = plt.hist(privLB[:,1],bins = np.linspace(xmin,xmax,150), color="b", alpha =0.3)
hist = plt.hist(pubLB[:,1],bins = np.linspace(xmin,xmax,150), color="r", alpha =0.3)


plt.title(title)
matplotlib.rc('font', **font)

# %%
sortedPriv=tb.sortByColumn(privLB,0)
sortedPub=tb.sortByColumn(pubLB,0)
sortedDiffs = np.empty([len(sortedPub[:,2]),6])

sortedDiffs[:,0] = np.copy(sortedPriv[:,0]) #user
sortedDiffs[:,1] = np.copy(sortedPriv[:,2]) #priv rank
sortedDiffs[:,2] = np.copy(sortedPub[:,2]-sortedPriv[:,2]) #rankdiff
sortedDiffs[:,3] = np.copy(abs(sortedPub[:,2]-sortedPriv[:,2])) #rankdiff
sortedDiffs[:,4] = np.copy(sortedPub[:,1]-sortedPriv[:,1]) #scorediff
sortedDiffs[:,5] = np.copy(abs(sortedPub[:,1]-sortedPriv[:,1])) #scorediff

# %%
privLB[1698]
# Out:
# array([  9.40970000e+04,   5.86480000e-01,   1.69900000e+03])

# %%
["bm: random submission",privLB[1698][1],1699]
# Out:
# ['bm: random submission', 0.58648, 1699]

# %%
sortedDiffs = tb.sortByColumn(sortedDiffs ,5)

# %%
benchmarkData = [["bm: random submission",privLB[1698,1],1699],
                 ["bm: simple window",privLB[1606,1],1607],
                 ["bm: naive Bayes starting kit",privLB[1462,1],1463],
                 ["bm: simple TMVA boosted trees",privLB[991,1],992],
                 ["bm: multiboost",privLB[902,1],903]
                ]

# %%
amsData = [["logistic Regression",2.06934119373163,1429],
           ["k Nearest Neighbors",3.18323451660961,996],
           ["sklearn.GradientBoostingClassifier",3.45097313747456,838],
           ["XGBoost",3.71268472156738,65],
           ["XGBoost original sumission",privLB[44,1],45],
           ["winner",privLB[0,1],1]           
          ]

# %%
data = vstack((benchmarkData,amsData))

# %%
ranks = np.array(data[:,2],dtype=float)

# %%
data = tb.sortByColumn(data,1)

# %%
ranks = np.array(data[:,2],dtype=float)
ams = np.array(data[:,1],dtype=float)
names = np.array(data[:,0],dtype="<U40")

# %%
mainFig = plt.figure(figsize=(16,12))
ax = mainFig.add_subplot(111)

font = {'size'   : 15}
matplotlib.rc('font', **font)

xmax = pubLB[:,1].max()
plt.axis([1779,-10,0.,4.])

plt.plot(pubLB[:,2],pubLB[:,1], linewidth=2, alpha = 0.8)
plt.plot(privLB[:,2],privLB[:,1], "r", linewidth=2, alpha = 0.8)

#annotations made by hand for useful positioning
#random submission
plt.annotate(names[0],xy = (ranks[0],ams[0]), xytext=(-30,-90),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#simple windows
plt.annotate(names[1],xy = (ranks[1],ams[1]), xytext=(-10,-180),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#naive bayes
plt.annotate(names[2],xy = (ranks[2],ams[2]), xytext=(5,-220),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#logistic regression
plt.annotate(names[3],xy = (ranks[3],ams[3]), xytext=(100,-175),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#kNN
plt.annotate(names[4],xy = (ranks[4],ams[4]), xytext=(-50,-325),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#simple TMVA
plt.annotate(names[5],xy = (ranks[5],ams[5]), xytext=(50,-275),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#multiboost
plt.annotate(names[6],xy = (ranks[6],ams[6]), xytext=(100,-250),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#sklearn gbc
plt.annotate(names[7],xy = (ranks[7],ams[7]), xytext=(125,-225),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#xgboost
plt.annotate(names[8],xy = (ranks[8],ams[8]), xytext=(-250,-150),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#original xgboost
plt.annotate(names[9],xy = (ranks[9],ams[9]), xytext=(-205,-100),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))
#winner
plt.annotate(names[10],xy = (ranks[10],ams[10]), xytext=(-500,0),
                 xycoords = "data", textcoords='offset points',arrowprops = dict(arrowstyle="-"))

overridex = {
    'fontsize'            : 'xx-large',
    'verticalalignment'   : 'top',
    'horizontalalignment' : 'center'
    }

overridey = {
   'fontsize'            : 'xx-large',
   'verticalalignment'   : 'baseline',
   'horizontalalignment' : 'center',
   'rotation'            : 'vertical'
}


font = {'size'   : 20}
matplotlib.rc('font', **font)

plt.xlabel("rank",overridex)
plt.ylabel("AMS",overridey)


plt.legend(('public Leaderboard', 'private Leaderboard'),loc=4)
#data
#plt.bar(left = ranks, height = ams,width= 1,alpha=1)

savePath = ("F:\BA_git\Docs\latex\Thesis\src\\v4\images" + "\\" + "amscompare")
mainFig.savefig(savePath)

# %%
n_rankdiff = rankdiff.copy()

# %%
for i in range(0,len(n_rankdiff)):
    maxDiff = rankdiff.max()
    minDiff = rankdiff.min()
    if rankdiff[i]>0:
        n_rankdiff[i] = rankdiff[i]/maxDiff
    elif rankdiff[i]<0:
        n_rankdiff[i] = -(rankdiff[i]/minDiff)
    else:
        n_rankdiff[i]=0.

# %%
mainFig = plt.figure(figsize=(20,15))
ax = mainFig.add_subplot(111)

xmax = 1769
xmin = 0
plt.axis([xmax,xmin,xmax,xmin])

plt.scatter(sortedPub[:,2],sortedPriv[:,2],s=100,edgecolor="",c=abs_scorediff,cmap="Set1")

xName = "Public Rank"
yName = "Private Rank"
    
plt.xlabel(xName)
plt.ylabel(yName)

plt.plot(sortedPriv[:,2],sortedPriv[:,2],color="black")

cbar = plt.colorbar()
cbar.set_label("ams-Difference (= abs(private ams - public ams))")

# %%
n_scorediff = scorediff.copy()
for i in range(0,len(n_scorediff)):
    maxDiff = scorediff.max()
    minDiff = scorediff.min()
    if scorediff[i]>0:
        n_scorediff[i] = scorediff[i]/maxDiff
    elif scorediff[i]<0:
        n_scorediff[i] = -(scorediff[i]/minDiff)
    else:
        n_scorediff[i]=0.

# %%
mainFig = plt.figure(figsize=(20,15))
ax = mainFig.add_subplot(111)

#xmax = pubLB[:,1].max()
plt.axis([3.,4.,3.,4.])

plt.scatter(sortedPriv[:,1],sortedPub[:,1],s=50,edgecolor="",c=n_scorediff,cmap="jet")

cbar = plt.colorbar()
cbar.set_label("Score-Difference (= abs(private ams - public ams))")

#plt.plot(privLB[:,2],privLB[:,1])

# %%
mainFig = plt.figure(figsize=(20,15))
ax = mainFig.add_subplot(111)

#xmax = pubLB[:,1].max()
plt.axis([-300,300,-0.1,0.1])

plt.scatter(rankdiff,scorediff,s=50,edgecolor="",c=scorediff,cmap="jet")

cbar = plt.colorbar()
cbar.set_label("Score-Difference (= abs(private ams - public ams))")

#plt.plot(privLB[:,2],privLB[:,1])

# %%
rec_data ,rec_header = tb.getRecord()

# %%
rec_data_sorted = tb.sortByColumn(rec_data,0)

# %%
rec_data_sorted.shape
# Out:
# (1104, 20)

# %%
def extractRecord(nameList, record, r_header):

    array = []
    for row in record:
        if row[0] in nameList:
            array.append(row)
    n_array = np.array(array)
    
    n_header = rec_header[:7]
    for i in range(7,len(rec_header)):
        if len(n_array[0,i].split("=")) < 2:
            break
        else:
            n_header.append(n_array[0,i].split("=")[0])
    
    n_array = n_array[:,:len(n_header)]
    
    for row in n_array:
        for i in range(7,len(n_header)):
            row[i] = row[i].split("=")[1]
            

    return n_array,n_header

# %%
rec_xgb,xgb_header = extractRecord(["xgboost"],rec_data_sorted,rec_header)
rec_gbc,gbc_header = extractRecord(["gbc"],rec_data_sorted,rec_header)
rec_log,log_header = extractRecord(["log Reg","log Reg CV"],rec_data_sorted,rec_header)
rec_knn,knn_header = extractRecord(["kNN"],rec_data_sorted,rec_header)

# %%
rec_knn_6 = []
for row in rec_knn:
    if row[1] == "header_6":
        rec_knn_6.append(row)
rec_knn_6 = np.array(rec_knn_6)

# %%
xydata=np.vstack((rec_knn_6[:,3],rec_knn_6[:,8])).transpose().astype(float)

# %%
mainFig = plt.figure(figsize=(16,12))
ax = mainFig.add_subplot(111)

font = {'size'   : 15}
matplotlib.rc('font', **font)

#xmax = pubLB[:,1].max()
plt.axis([1,311,2.9,3.2])

xydata=tb.sortByColumn(xydata,1)
x=xydata[:,1]
y=xydata[:,0]

plt.scatter(x,y,c="r", alpha = 0.8)
#plt.scatter(rec_xgb[:,4],rec_xgb[:,3], alpha = 0.8)

# Fit 
coefficients = np.polyfit(np.log(x),y,3) # Use log(x) as the input to polyfit.
fit = np.poly1d(coefficients) 

#plt.plot(x,y,"o",label="data")
plt.plot(x,fit(np.log(x)),"--", label="fit")


font = {'size'   : 20}
matplotlib.rc('font', **font)

overridex = {
    'fontsize'            : 'xx-large',
    'verticalalignment'   : 'top',
    'horizontalalignment' : 'center'
    }

overridey = {
   'fontsize'            : 'xx-large',
   'verticalalignment'   : 'baseline',
   'horizontalalignment' : 'center',
   'rotation'            : 'vertical'
}

plt.xlabel("k",overridex)
plt.ylabel("public AMS",overridey)

font = {'size'   : 30}
matplotlib.rc('font', **font)

plt.legend(("logarithmic fit",'kNN with Set 6'),loc=4)
#data
#plt.bar(left = ranks, height = ams,width= 1,alpha=1)

savePath = ("F:\BA_git\Docs\latex\Thesis\src\\v4\images" + "\\" + "knn_ams")
mainFig.savefig(savePath)

# %%
xydata=np.vstack((rec_knn_6[:,6],rec_knn_6[:,8])).transpose().astype(float)

# %%
mainFig = plt.figure(figsize=(16,12))
ax = mainFig.add_subplot(111)

font = {'size'   : 15}
matplotlib.rc('font', **font)

#xmax = pubLB[:,1].max()
#plt.axis([1,311,2.9,3.2])

xydata=tb.sortByColumn(xydata,1)
x=xydata[:,1]
y=xydata[:,0]

plt.scatter(x,y,c="r", alpha = 0.8)
#plt.scatter(rec_xgb[:,4],rec_xgb[:,3], alpha = 0.8)

# Fit 
coefficients = np.polyfit(x,y,1) 
fit = np.poly1d(coefficients) 

#plt.plot(x,y,"o",label="data")
plt.plot(x,fit(x),"--", label="fit")

font = {'size'   : 30}
matplotlib.rc('font', **font)
    

overridex = {
    'fontsize'            : 'xx-large',
    'verticalalignment'   : 'top',
    'horizontalalignment' : 'center'
    }

overridey = {
   'fontsize'            : 'xx-large',
   'verticalalignment'   : 'baseline',
   'horizontalalignment' : 'center',
   'rotation'            : 'vertical'
}

font = {'size'   : 20}
matplotlib.rc('font', **font)

plt.xlabel("k",overridex)
plt.ylabel("prediction time in seconds",overridey)

plt.legend(('linear fit' , 'kNN with Set 6'),loc=4)
#data
#plt.bar(left = ranks, height = ams,width= 1,alpha=1)

savePath = ("F:\BA_git\Docs\latex\Thesis\src\\v4\images" + "\\" + "knn_speed")
mainFig.savefig(savePath)

# %%
for row in tb.sortByColumn(rec_xgb,5):
    if float(row[3]) > 2.06934:
        print(row)
        break
for row in tb.sortByColumn(rec_xgb,5):
    if float(row[3]) > 3.18323:
        print(row)
        break
print(tb.sortByColumn(rec_xgb,3)[-1])
# Out:
# ['xgboost' 'header_all' '2.13937513333' '2.19428117559891'
#  '2.20533097572820' '0.91599702835083' '1.54508709907531' '0.14' '2' '5'
#  '0.1' '0.9' 'auc' 'ams@0.14']
# ['xgboost' 'header_all' '2.13937513333' '3.20720656549569'
#  '3.26719390608683' '10.0206091403961' '2.00612592697143' '0.14' '40' '5'
#  '0.1' '0.9' 'auc' 'ams@0.14']
# ['xgboost' 'header_all' '2.4321543' '3.66421262680941' '3.71268472156738'
#  '997.632616996765' '57.4933519363403' '0.145' '2500' '9' '0.01' '0.9'
#  'auc' 'ams@0.14']

# %%
0.91599702835083+1.54508709907531
# Out:
# 2.46108412742614

# %%
rec_pubams=tb.sortByColumn(rec_data,3)

# %%
gotIT = []
best = []
for row in reversed(rec_pubams):
    if row[0] not in gotIT:
        gotIT.append(row[0])
        best.append(row)
best = np.array(best)

# %%
best = tb.sortByColumn(best,3)

# %%
best
# Out:
# array([['log Reg CV', 'header_3', '0.73507', '1.96216755909995',
#         '1.98149424825609', '33.3609240055084', '0.26706004142761',
#         'threshold=0.4444', 'Cs=1', 'penalty=l1', "scoring = 'roc_a",
#         'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None',
#         'None'],
#        ['log Reg', 'header_8', '0.73926', '2.04480142600976',
#         '2.06934119373163', '3.66517996788024', '0.21003699302673',
#         'threshold=0.4444', 'C=0.1', 'penalty=l2', 'None', 'None', 'None',
#         'None', 'None', 'None', 'None', 'None', 'None', 'None'],
#        ['kNN', 'header_6', '0.81892', '3.18534579809683',
#         '3.17144377327013', '1.25601601600646', '123.669127941131',
#         'threshold=0.7777', 'k=297', 'p=1', 'None', 'None', 'None', 'None',
#         'None', 'None', 'None', 'None', 'None', 'None'],
#        ['gbc', 'header_all', '0.870048', '3.23356085563658',
#         '3.42604955414675', '5007.69863915443', '5.73332595825195',
#         'threshold=0.6666', 'trees_=100', 'depth_=12', 'eta_=0.01',
#         'subsample_=0.9', 'None', 'None', 'None', 'None', 'None', 'None',
#         'None', 'None'],
#        ['xgboost', 'header_all', '2.4321543', '3.66421262680941',
#         '3.71268472156738', '997.632616996765', '57.4933519363403',
#         'Threshold=0.145', 'steps_=2500', 'depth_=9', 'eta_=0.01',
#         'subsample_=0.9', 'eval_1=auc', 'eval_2=ams@0.14', 'None', 'None',
#         'None', 'None', 'None', 'None']],
#       dtype='<U16')

# %%
xgbData = []
for row in rec_xgb:
    if row[7] == '0.14' and row[8] == '2500' and row[10] == '0.01':
        xgbData.append([row[1],row[3]])
xgbData = np.array(xgbData)
xgbData = xgbData[:-1]

# %%
knnData = []
for row in rec_knn:
    if row[8] == '201' and row[9] == '1':
        knnData.append([row[1],row[3]])
knnData = np.array(knnData)
knnData = np.vstack((tb.sortByColumn(knnData,0)[1:7],tb.sortByColumn(knnData,0)[-4:]))

# %%
logData = []
for row in rec_log:
    if row[-1] == 'l2' and row[-2] == '0.1':
        logData.append([row[1],row[3]])
logData = np.array(logData)
logData = tb.sortByColumn(logData,0)
logData = np.vstack((tb.sortByColumn(logData,0)[:-4],tb.sortByColumn(logData,0)[-1]))

# %%
def transform(data):
    for row in data:
        setX = row[0].split("_")[1]
        if setX == 'x':
            setX = '9'
        if setX == 'all':
            setX = '10'
        row[0] = setX
    return tb.sortByColumn(np.array(data).astype(float),0)

# %%
xgbData = transform(xgbData)
knnData = transform(knnData)
logData = transform(logData)

# %%
mainFig = plt.figure(figsize=(16,12))
ax = mainFig.add_subplot(111)

font = {'size'   : 18}
matplotlib.rc('font', **font)

#width = 0.25

plt.plot(xgbData[:,0],xgbData[:,1],"r-o")
plt.plot(knnData[:,0],knnData[:,1],"b-o")
plt.plot(logData[:,0],logData[:,1],"g-o")

#plt.scatter(rec_xgb[:,4],rec_xgb[:,3], alpha = 0.8)



#plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

overridex = {
    'fontsize'            : 'xx-large',
    'verticalalignment'   : 'top',
    'horizontalalignment' : 'center'
    }

overridey = {
   'fontsize'            : 'xx-large',
   'verticalalignment'   : 'baseline',
   'horizontalalignment' : 'center',
   'rotation'            : 'vertical'
}

plt.xlabel("feature sets",overridex)
plt.ylabel("public AMS",overridey)


#plt.yticks(np.linspace(2.5,4.5,11))
plt.xticks(np.arange(1,11),[
            "Set 1",
            "Set 2",
            "Set 3",
            "Set 4",
            "Set 5",
            "Set 6",
            "Set 7",
            "Set 8",
            "Set 9",
            "Set all"
        ])

plt.axis([0,11,1.75,4.0])
#
#font = {'size'   : 20}
#matplotlib.rc('font', **font)
plt.legend(('XGBoost; 2500 trees, depth 9','kNN; k=201','Logistic Regression; C=0.1'),loc=9)
#dat
#plt.bar(left = ranks, height = ams,width= 1,alpha=1)

savePath = ("F:\BA_git\Docs\latex\Thesis\src\\v4\images" + "\\" + "setperformance")
mainFig.savefig(savePath)

# %%
logData = tb.sortByColumn(logData,0)[:-3]

# %%
best_xgb = np.vstack((rec_xgb[:,4],rec_xgb[:,5])).astype(float)

# %%
rec_gbc_all = []
for row in rec_gbc:
    if row[1] == "header_all":
        if row[10] == "0.01":
            rec_gbc_all.append(row)
rec_gbc_all = np.array(rec_gbc_all)

# %%
rec_xgb_all_3000 = []
for row in rec_xgb:
    if row[1] == "header_all":
        if row[10] == "0.01" and row[8] == "3000":
            rec_xgb_all_3000.append(row)
rec_xgb_all_3000 = np.array(rec_xgb_all_3000)

# %%
rec_xgb_all_1000 = []
for row in rec_xgb:
    if row[1] == "header_all":
        if row[10] == "0.01" and row[8] == "1000":
            rec_xgb_all_1000.append(row)
rec_xgb_all_1000 = np.array(rec_xgb_all_1000)

# %%
rec_xgb_all_100 = []
for row in rec_xgb:
    if row[1] == "header_all":
        if row[9] in ['6','9','12']:
            if row[10] == "0.01" and row[8] == "100":
                rec_xgb_all_100.append(row)
rec_xgb_all_100 = np.array(rec_xgb_all_100)

# %%
mainFig = plt.figure(figsize=(12,10))
ax = mainFig.add_subplot(111)

font = {'size'   : 18}
matplotlib.rc('font', **font)

width = 0.25

plt.bar(left=rec_gbc_all[:,9].astype(float),height = rec_gbc_all[:,3].astype(float), alpha = 1, width = width)
plt.bar(left=rec_xgb_all_100[:,9].astype(float)+width,height = rec_xgb_all_100[:,3].astype(float), color = "r", alpha = 1, width = width)
plt.bar(left=rec_xgb_all_1000[:,9].astype(float)+2*width,height = rec_xgb_all_1000[:,3].astype(float), color = "y", alpha = 1, width = width)
plt.bar(left=rec_xgb_all_3000[:,9].astype(float)+3*width,height = rec_xgb_all_3000[:,3].astype(float), color = "g", alpha = 1, width = width)
#plt.scatter(rec_xgb[:,4],rec_xgb[:,3], alpha = 0.8)



#plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

overridex = {
    'fontsize'            : 'xx-large',
    'verticalalignment'   : 'top',
    'horizontalalignment' : 'center'
    }

overridey = {
   'fontsize'            : 'xx-large',
   'verticalalignment'   : 'baseline',
   'horizontalalignment' : 'center',
   'rotation'            : 'vertical'
}

plt.xlabel("tree depth",overridex)
plt.ylabel("public AMS",overridey)


#plt.yticks(np.linspace(2.5,4.5,11))
plt.xticks([6,9,12])

plt.axis([5,14,2.75,4.0])

#font = {'size'   : 20}
#matplotlib.rc('font', **font)
plt.legend(('sklearn.GradientBoostingClassifier, 100 trees','XGBoost, 100 trees','XGBoost, 1000 trees', 'XGBoost, 3000 trees'),loc=9)
#data
#plt.bar(left = ranks, height = ams,width= 1,alpha=1)

savePath = ("F:\BA_git\Docs\latex\Thesis\src\\v4\images" + "\\" + "xgb-gbc")
mainFig.savefig(savePath)

# %%
pub_url = "https://www.kaggle.com/c/flavours-of-physics/leaderboard/public"
priv_url = "https://www.kaggle.com/c/flavours-of-physics/leaderboard/private"
flav_pub_lB = kD.getLeaderBoard(pub_url)
flav_priv_lB = kD.getLeaderBoard(priv_url)

# %%
flav_sortedPriv=tb.sortByColumn(flav_priv_lB,0)
flav_sortedPub=tb.sortByColumn(flav_pub_lB,0)

flav_rankdiff = np.copy(flav_sortedPub[:,2]-flav_sortedPriv[:,2])
flav_abs_rankdiff = abs(np.copy(flav_sortedPub[:,2]-flav_sortedPriv[:,2]))
flav_scorediff = np.copy(flav_sortedPub[:,1]-flav_sortedPriv[:,1])
flav_abs_scorediff = abs(np.copy(flav_sortedPub[:,1]-flav_sortedPriv[:,1]))

# %%
xData.max()
# Out:
# 1785.0

# %%
# %pylab inline

font = {'size'   : 20}

mainFig = plt.figure(figsize=(12,9))
ax = mainFig.add_subplot(111)

xData = flav_sortedPub[:,2]
yData = flav_sortedPriv[:,2]

#colors = generateLabelsColors(labels)

#scale = 0.5
#xmin,xmax = scaleAxis(xData,scale)
#ymin,ymax = scaleAxis(yData,scale)
plt.Normalize()
scat = plt.scatter(xData, yData, s=100, edgecolor="gray",  c=flav_rankdiff, cmap="jet")   
  
xName = "Public Rank"
yName = "Private Rank"
    
overridex = {
    'fontsize'            : 'xx-large',
    'verticalalignment'   : 'top',
    'horizontalalignment' : 'center'
    }

overridey = {
   'fontsize'            : 'xx-large',
   'verticalalignment'   : 'baseline',
   'horizontalalignment' : 'center',
   'rotation'            : 'vertical'
}

plt.xlabel(xName,overridex)
plt.ylabel(yName,overridey)

xmax = 690
xmin = -20
    
plt.axis([xmax,xmin,xmax,xmin])

x = np.arange(xmin,xmax)
xy = plt.plot(x,x,color="black")

title = ("Shake-Up of 'Flavours of Physics'")

coord = int(abs(xmax-xmin)/2)

matplotlib.rc('font', **font)
plt.title(title)

cbar = plt.colorbar()
cbar.set_label("Rank-Difference (= |private rank - public rank|)")

plt.annotate("difference = 0",xy = (coord,coord), xytext=(+100,-200),
             xycoords = "data", textcoords='offset points',
             arrowprops = dict(arrowstyle="-"))

savePath = ("F:\BA_git\Docs\latex\Thesis\src\\v4\images" + "\\" + "flavShakeup")
mainFig.savefig(savePath)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['title', 'hist']
# `%matplotlib` prevents importing * from pylab and numpy
